# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import locale # to format currency as USD
locale.setlocale( locale.LC_ALL, '' )

# Import API key
from api_keys import api_key

# Output File (CSV)
output_data_file = "tmbddata_rev2.csv"

# %%
## Generate Movies Database from TMBD API

r = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&sort_by=revenue.desc')
highest_revenue_ever = r.json()
r.json()
# Out:
# {'page': 1,
#  'total_results': 10000,
#  'total_pages': 500,
#  'results': [{'popularity': 1.4,
#    'vote_count': 1,
#    'video': False,
#    'poster_path': '/uslZWeamLmEg0oWsGGLXu8cvHb5.jpg',
#    'id': 661422,
#    'adult': False,
#    'backdrop_path': None,
#    'original_language': 'en',
#    'original_title': 'Arrietty (UK Voice Cast)',
#    'genre_ids': [12, 16, 10751],
#    'title': 'Arrietty (UK Voice Cast)',
#    'vote_average': 10,
#    'overview': "Arrietty, a tiny teenager, lives with her parents in the recesses of a suburban home, unbeknownst to the homeowner and housekeeper. Like others of her kind, Arrietty remains hidden from her human hosts, but occasionally ventures forth from beneath the floorboards to borrow sugar cubes and other supplies. A secret friendship forms when 12-year-old Sho meets Arrietty, but their relationship could spell danger for Arrietty's family.",
#    'release_date': '2011-07-29'},
#   {'popularity': 2.831,
#    'id': 652264,
# ...

# %%
#Create dataframe from JSON

columns = ['film', 'revenue', 'budget', 'release_date']
df = pd.DataFrame(columns=columns)
for film in highest_revenue_films_ever:
    film_revenue = requests.get('https://api.themoviedb.org/3/movie/'+ str(film['id']) +'?api_key='+ api_key+'&language=en-US')
    film_revenue = film_revenue.json()
    df.loc[len(df)]=[film['title'],film_revenue['revenue'], (film_revenue['budget'] * -1), film_revenue['release_date']]

# %%
def film_revenue(id, api_key):
    
    url = "https://api.themoviedb.org/3/movie/"
    payload = {
        "appid": api_key,
        "q": id
    }
    r = requests.get(url, params=payload)
    
    if r.status_code == 200:
        return r.json()
    else:
        return None

all_cities = []
for city in cities:
    result = get_current_weather(city, api_key)
    if result:
        all_cities.append(result)
df = pd.DataFrame([{
    "name": d["name"],
    "date_time": d["dt"],
    "lat": d["coord"]["lat"],
    "lon": d["coord"]["lon"],
    "temp": d["main"]["temp"],
    "temp_min": d["main"]["temp_min"],
    "temp_max": d["main"]["temp_max"],
    "humidity": d["main"]["humidity"],
    "wind_speed": d["wind"]["speed"],
    "clouds_percent": d["clouds"]["all"],
} for d in all_cities])
